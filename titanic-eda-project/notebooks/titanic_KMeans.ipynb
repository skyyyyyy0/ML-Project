# %%
# Import libraries
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
df = pd.read_csv('../data/train.csv')

# Select and clean data
df = df[['Pclass', 'Fare', 'Age']].dropna()  # Drop rows where Age is missing

# Fit K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict((df[['Pclass', 'Fare', 'Age']]))

# %%
# Plot the clusters 
plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x='Fare', y='Age', hue='Cluster', palette='Set2')
plt.title('Passenger Clusters by Fare and Age')
plt.xlabel('Fare')
plt.ylabel('Age')
plt.legend(title='Cluster')
plt.show()
